# %% [markdown]
# nn.Module
# pytorch 라이브러리에서 제공하는 기본 클래스
# 신경망 모델 구현할 때 사용, 모델의 구조, 매개변수 , 그래디언트 및 기타 관련 기능 관리
# 주로 2 가지 메소드를 정의한다
#
# 1.__init__(self) : 모델의 레이어와 구조 초기화
#
# 2.forward(self,x) : 모델의 순전파 정의, 입력 텐서 x를 받아 모델을 통해 텐서를 전달하고 결과를 반환한다
#
# nn.Module 클래스를 사용하면 모델의 매개변수와 그래디언트 관리, 모델 저장 및 불러오기, 디바이스 간 이동 등 다양한 기능 쉽게 활용
